# %% [markdown]
# # Christmas Package
# Info for Anthony
# Or anyone else

# %%
from MissSanta import LilElfCalculations
LilElfCalculations.helloSanta()
LilElfCalculations.helloElfName("Gerald")
print(LilElfCalculations.countStock(12, 20))
LilElfCalculations.KidsReceivedCoal(208)

# %%
from MissSanta import ChristmasLove

print(ChristmasLove.ChristmasLove("Santa", "Miss Santa"))
print(ChristmasLove.badLove("Santa", "Miss Santa"))
# Out:
# Santa and Miss Santa have a match % of 67.0% <3 !
# 100% match
