# %% [markdown]
# # Super Package: DSPSLovers
# Test my package here!

# %%
from mypackage import TrueLove
print(TrueLove.calculateTrueLove("Jack Black", "Princess Peach"))
print(TrueLove.crappyLove("Jack Black", "Princess Peach"))
# Out:
# 17.0% match!
# 70% match

# %%
from mypackage import simpleFunctions as SF
print(SF.power(2, 4))
# Out:
# 16
